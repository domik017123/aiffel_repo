# %% [markdown]
# # Q17. pix2pix: cGAN(U-Net-Generator, PatchGAN)

# %% [markdown]
# ## 1. 데이터 로드 및 Augmentation

# %% [markdown]
# ### 1-1. 데이터 로드

# %%
import tensorflow as tf
import os
import cv2
import numpy as np

import pathlib
import time
import datetime

from matplotlib import pyplot as plt
from IPython import display

# %%
data_path = os.getenv('HOME')+'/aiffel/conditional_generation/data/cityscapes/'
sample_image = tf.io.read_file(str(data_path+'train/1.jpg'))
sample_image = tf.io.decode_jpeg(sample_image)
print(sample_image.shape)
plt.figure(figsize=(20,10))
plt.figure()
plt.imshow(sample_image)
# Out:
# (256, 512, 3)

# %%
def load(image_file):
    # image file to a uint8 tensor(0~255)
    image = tf.io.read_file(image_file)
    image = tf.io.decode_jpeg(image)
    
    # Split into two tensors
    w = tf.shape(image)[1] // 2
    input_image = image[:, :w, :]
    real_image = image[:, w:, :] 

    # Convert both images to float32 tensors
    input_image = tf.cast(input_image, tf.float32)
    real_image = tf.cast(real_image, tf.float32)

    return real_image, input_image


sample_path = data_path + 'train/1.jpg'
inp, re = load(sample_path)
print(re[0,0])

plt.figure(figsize=(20,10))
plt.subplot(1,2,1); plt.imshow(inp / 255.0)
plt.subplot(1,2,2); plt.imshow(re / 255.0)
# Out:
# tf.Tensor([175. 205. 197.], shape=(3,), dtype=float32)

# %% [markdown]
# ### 1-2. Augmentation

# %% [markdown]
# - random_jitter 함수 정의
# 1. resizing 256x256 to 286x286
# 2. random cropping
# 3. random mirroring

# %%
# The training set consist of 1000 images
BUFFER_SIZE = 400
# The batch size of 1 produced better results for the U-Net in the original pix2pix experiment
BATCH_SIZE = 1
# Each image is 256x256 in size
IMG_WIDTH = 256
IMG_HEIGHT = 256

def resize(input_image, real_image, height, width):
    input_image = tf.image.resize(input_image, [height, width], method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
    real_image = tf.image.resize(real_image, [height, width], method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
    
    return input_image, real_image

def random_crop(input_image, real_image):
    stacked_image = tf.stack([input_image, real_image])
    cropped_image = tf.image.random_crop(stacked_image, size=[2, IMG_HEIGHT, IMG_WIDTH, 3])

    return cropped_image[0], cropped_image[1]

@tf.function()
def random_jitter(input_image, real_image):
    #resizing
    input_image, real_image = resize(input_image, real_image, 286, 286)
    #cropping
    input_image, real_image = random_crop(input_image, real_image)
    #random mirroring
    if tf.random.uniform(()) > 0.5:
        input_image = tf.image.flip_left_right(input_image)
        real_image = tf.image.flip_left_right(real_image)

    return input_image, real_image

# %%
plt.figure(figsize=(20, 10))
for i in range(4):
    rj_inp, rj_re = random_jitter(inp, re)
    plt.subplot(2, 4, 2*i + 1)
    plt.imshow(rj_inp / 255.0)
    plt.subplot(2, 4, 2*i + 2)
    plt.imshow(rj_re / 255.0)
    plt.axis('off')
plt.show()

# %% [markdown]
# ### 1-3. 훈련/테스트셋 전처리 및 입력 파이프라인 구축

# %%
def normalize(input_image, real_image):
    input_image = (input_image / 127.5) - 1
    real_image = (real_image / 127.5) - 1

    return input_image, real_image

# %%
def load_image_train(image_file):
    input_image, real_image = load(image_file)
    input_image, real_image = random_jitter(input_image, real_image)
    input_image, real_image = normalize(input_image, real_image)

    return input_image, real_image

def load_image_test(image_file):
    input_image, real_image = load(image_file)
    input_image, real_image = resize(input_image, real_image, IMG_HEIGHT, IMG_WIDTH)
    input_image, real_image = normalize(input_image, real_image)

    return input_image, real_image

# %%
train_dataset = tf.data.Dataset.list_files(str(data_path +'train/*.jpg'))
train_dataset = train_dataset.map(load_image_train, num_parallel_calls=tf.data.AUTOTUNE)
train_dataset = train_dataset.shuffle(BUFFER_SIZE)
train_dataset = train_dataset.batch(BATCH_SIZE)

# %%
try:
    test_dataset = tf.data.Dataset.list_files(str(data_path +'val/*.jpg'))
except tf.errors.InvalidArgumentError:
    test_dataset = tf.data.Dataset.list_files(str(data_path +'val/*.jpg'))
test_dataset = test_dataset.map(load_image_test)
test_dataset = test_dataset.batch(BATCH_SIZE)

# %% [markdown]
# ## 2. U-Net-Generator 구축

# %% [markdown]
# ### 2-1. 인코더 및 디코더 정의

# %%
from tensorflow.keras import layers, Input, Model

class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu= layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

class Encoder(layers.Layer):
    def __init__(self):
        super(Encoder, self).__init__()
        filters = [64,128,256,512,512,512,512,512]
        
        # 첫번째 EncoderBlock의 경우 Batch Normalization을 생략
        self.blocks = [] 
        for f in filters:
            self.blocks.append(
                EncodeBlock(f, use_bn=False if f==64 else True)
            )
    def call(self, x):
        for block in self.blocks:
            x = block(x)
        return x
    
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

Encoder().get_summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# encode_block (EncodeBlock)   (None, 128, 128, 64)      3072
# _________________________________________________________________
# encode_block_1 (EncodeBlock) (None, 64, 64, 128)       131584
# _________________________________________________________________
# encode_block_2 (EncodeBlock) (None, 32, 32, 256)       525312
# _________________________________________________________________
# encode_block_3 (EncodeBlock) (None, 16, 16, 512)       2099200
# _________________________________________________________________
# encode_block_4 (EncodeBlock) (None, 8, 8, 512)         4196352
# _________________________________________________________________
# encode_block_5 (EncodeBlock) (None, 4, 4, 512)         4196352
# _________________________________________________________________
# encode_block_6 (EncodeBlock) (None, 2, 2, 512)         4196352
# _________________________________________________________________
# encode_block_7 (EncodeBlock) (None, 1, 1, 512)         4196352
# =================================================================
# Total params: 19,544,576
# Trainable params: 19,538,688
# Non-trainable params: 5,888
# _________________________________________________________________

# %%
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

    
class Decoder(layers.Layer):
    def __init__(self):
        super(Decoder, self).__init__()
        filters = [512,512,512,512,256,128,64]
        # 3번째 block까지 Dropout 사용
        # output 차원수 3, filter 사이즈 4, stride 2, padding = same
        self.blocks = [] 
        for i, f in enumerate(filters):
            if i < 3:
                self.blocks.append(DecodeBlock(f, dropout=True))
            else:
                self.blocks.append(DecodeBlock(f, dropout=False))

        self.blocks.append(layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False))

    def call(self, x):
        for block in self.blocks:
            x = block(x)
        return x
            
    def get_summary(self, input_shape=(1,1,512)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()
    
Decoder().get_summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 1, 1, 512)]       0
# _________________________________________________________________
# decode_block (DecodeBlock)   (None, 2, 2, 512)         4196352
# _________________________________________________________________
# decode_block_1 (DecodeBlock) (None, 4, 4, 512)         4196352
# _________________________________________________________________
# decode_block_2 (DecodeBlock) (None, 8, 8, 512)         4196352
# _________________________________________________________________
# decode_block_3 (DecodeBlock) (None, 16, 16, 512)       4196352
# _________________________________________________________________
# decode_block_4 (DecodeBlock) (None, 32, 32, 256)       2098176
# _________________________________________________________________
# decode_block_5 (DecodeBlock) (None, 64, 64, 128)       524800
# _________________________________________________________________
# decode_block_6 (DecodeBlock) (None, 128, 128, 64)      131328
# _________________________________________________________________
# conv2d_transpose_7 (Conv2DTr (None, 256, 256, 3)       3072
# =================================================================
# Total params: 19,542,784
# Trainable params: 19,537,792
# Non-trainable params: 4,992
# _________________________________________________________________

# %% [markdown]
# ### 2-2. UNet skip connection 구현

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        #skip connection을 위한 리스트에 Encoder 출력 할당
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
            
        #Encoder의 마지막 출력은 features에서 제외
        features = features[:-1]
        
        #features의 역순으로 연결            
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()
    
    def get_plot(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        model = Model(inputs, self.call(inputs))
        return tf.keras.utils.plot_model(model, show_shapes=True, dpi=64)

UNetGenerator().get_plot()

# %% [markdown]
# ## 3. PatchGAN Discriminator 구현

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x
    

class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        filters = [64,128,256,512,1]
        self.blocks = [layers.Concatenate()]
        # custom padding: block 4>>5>>6(32>>31>>30)
        # receptive field: (1>>4>>7>>16>>34>>70)
        for i, f in enumerate(filters):
            if i < 3:
                stride = 2
                custom_pad = False
            else:
                stride = 1
                custom_pad = True
            
            use_bn = not(i==0 or i==len(filters)-1)
            act = not(i== len(filters) - 1)
            
            self.blocks.append(DiscBlock(f, stride, custom_pad, use_bn, act))

        self.sigmoid = layers.Activation('sigmoid')
        
    def call(self, x, y):
        x = self.blocks[0]([x, y])
        for block in self.blocks[1:]:
            x = block(x)
        out = self.sigmoid(x)
        return out
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()
    
    def get_plot(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape)
        model = Model((x, y), self.call(x, y))
        return tf.keras.utils.plot_model(model, show_shapes=True, dpi=64)
    
Discriminator().get_plot()

# %%
#Discriminator output: Patch 70x70 T/F classification
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %% [markdown]
# ## 4. Generator/Discriminator 손실 및 훈련 루프 정의

# %% [markdown]
# ### 4-1. 손실 함수 및 훈련 루프 정의

# %%
from tensorflow.keras import losses
from tensorflow.keras import optimizers

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()
generator_optimizer = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
discriminator_optimizer = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

#Generator loss, L1 loss
def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

#Discriminator loss
def get_disc_loss(fake_disc, real_disc):
    disc_loss = bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)
    return disc_loss

@tf.function
def train_step(input_image, real_image):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # 생성자에 입력 스케치를 전달하여 가짜 컬러 이미지 생성
        fake_image = generator(input_image, training=True)

        # 판별자에 실제 컬러 이미지와 가짜 컬러 이미지를 전달하여 판별 결과 계산
        real_disc = discriminator(real_image, input_image, training=True)
        fake_disc = discriminator(fake_image, input_image, training=True)
        
        #Generator loss + lambda * L1 loss (lambda = 100)
        gene_loss, l1_loss = get_gene_loss(fake_image, real_image, fake_disc)
        gene_total_loss = gene_loss + 100*l1_loss
        
        #Discriminator loss
        disc_loss = get_disc_loss(fake_disc, real_disc)
        

    # 생성자와 판별자에 대한 그래디언트 계산
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)


    generator_optimizer.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_total_loss, l1_loss, disc_loss

# %% [markdown]
# ### 4-2. 학습

# %%
EPOCHS = 50

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (input_image, real_image) in enumerate(train_dataset):
        g_tot_loss, l1_loss, d_loss = train_step(input_image, real_image)
                
        # 10회 반복마다 손실을 출력합니다.
        if (i+1) % 10 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_tot_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[10]
# Generator_loss:34.0091
# L1_loss:0.3304
# Discriminator_loss:1.3504
#
# EPOCH[1] - STEP[20]
# Generator_loss:26.2244
# L1_loss:0.2491
# Discriminator_loss:1.0162
#
# EPOCH[1] - STEP[30]
# Generator_loss:20.9033
# L1_loss:0.2007
# Discriminator_loss:1.3556
#
# EPOCH[1] - STEP[40]
# Generator_loss:18.6897
# L1_loss:0.1763
# Discriminator_loss:1.1503
#
# EPOCH[1] - STEP[50]
# Generator_loss:31.6053
# L1_loss:0.3056
# Discriminator_loss:1.5410
#
# EPOCH[1] - STEP[60]
# Generator_loss:21.1609
# L1_loss:0.1947
# Discriminator_loss:1.2704
#
# EPOCH[1] - STEP[70]
# Generator_loss:25.6481
# L1_loss:0.2433
# Discriminator_loss:0.8769
#
# EPOCH[1] - STEP[80]
# Generator_loss:16.1746
# L1_loss:0.1512
# Discriminator_loss:1.1963
#
# EPOCH[1] - STEP[90]
# Generator_loss:17.9480
# L1_loss:0.1668
# Discriminator_loss:1.2726
#
# EPOCH[1] - STEP[100]
# Generator_loss:16.2903
# L1_loss:0.1547
# Discriminator_loss:1.2886
#
# EPOCH[1] - STEP[110]
# Generator_loss:19.7534
# L1_loss:0.1838
# Discriminator_loss:0.9743
#
# EPOCH[1] - STEP[120]
# Generator_loss:15.3924
# L1_loss:0.1423
# Discriminator_loss:1.0661
#
# EPOCH[1] - STEP[130]
# Generator_loss:18.4769
# L1_loss:0.1707
# Discriminator_loss:0.9448
#
# EPOCH[1] - STEP[140]
# Generator_loss:21.2427
# L1_loss:0.1999
# Discriminator_loss:0.7473
#
# EPOCH[1] - STEP[150]
# Generator_loss:17.6932
# L1_loss:0.1618
# Discriminator_loss:0.8337
#
# EPOCH[1] - STEP[160]
# Generator_loss:16.9793
# L1_loss:0.1452
# Discriminator_loss:0.6135
#
# EPOCH[1] - STEP[170]
# Generator_loss:21.1324
# L1_loss:0.1956
# Discriminator_loss:0.7223
#
# EPOCH[1] - STEP[180]
# Generator_loss:18.9259
# L1_loss:0.1768
# Discriminator_loss:1.1058
#
# EPOCH[1] - STEP[190]
# Generator_loss:15.4474
# L1_loss:0.1398
# Discriminator_loss:0.5980
#
# EPOCH[1] - STEP[200]
# Generator_loss:28.8288
# L1_loss:0.2654
# Discriminator_loss:0.4655
#
# EPOCH[1] - STEP[210]
# Generator_loss:17.4800
# L1_loss:0.1518
# Discriminator_loss:0.7118
#
# EPOCH[1] - STEP[220]
# Generator_loss:23.1142
# L1_loss:0.2239
# Discriminator_loss:0.8862
#
# EPOCH[1] - STEP[230]
# Generator_loss:17.5010
# L1_loss:0.1621
# Discriminator_loss:0.9771
#
# EPOCH[1] - STEP[240]
# Generator_loss:22.8438
# L1_loss:0.2033
# Discriminator_loss:0.5994
#
# EPOCH[1] - STEP[250]
# Generator_loss:23.8498
# L1_loss:0.2215
# Discriminator_loss:0.4119
#
# EPOCH[1] - STEP[260]
# Generator_loss:15.6415
# L1_loss:0.1487
# Discriminator_loss:1.5314
#
# EPOCH[1] - STEP[270]
# Generator_loss:17.5986
# L1_loss:0.1569
# Discriminator_loss:0.5115
#
# EPOCH[1] - STEP[280]
# Generator_loss:17.6271
# L1_loss:0.1546
# Discriminator_loss:0.8493
#
# EPOCH[1] - STEP[290]
# Generator_loss:19.9120
# L1_loss:0.1758
# Discriminator_loss:0.5009
#
# EPOCH[1] - STEP[300]
# Generator_loss:17.1491
# L1_loss:0.1670
# Discriminator_loss:1.5622
#
# EPOCH[1] - STEP[310]
# Generator_loss:14.8320
# L1_loss:0.1387
# Discriminator_loss:0.9204
#
# EPOCH[1] - STEP[320]
# Generator_loss:18.2210
# L1_loss:0.1631
# Discriminator_loss:0.4904
#
# EPOCH[1] - STEP[330]
# Generator_loss:15.0621
# L1_loss:0.1417
# Discriminator_loss:0.8289
#
# EPOCH[1] - STEP[340]
# Generator_loss:24.0106
# L1_loss:0.2319
# Discriminator_loss:0.9198
#
# EPOCH[1] - STEP[350]
# Generator_loss:17.5822
# L1_loss:0.1580
# Discriminator_loss:0.8316
#
# EPOCH[1] - STEP[360]
# Generator_loss:17.3493
# L1_loss:0.1513
# Discriminator_loss:0.5499
#
# EPOCH[1] - STEP[370]
# Generator_loss:23.2407
# L1_loss:0.2197
# Discriminator_loss:0.6028
#
# EPOCH[1] - STEP[380]
# Generator_loss:18.2122
# L1_loss:0.1676
# Discriminator_loss:0.5193
#
# EPOCH[1] - STEP[390]
# Generator_loss:18.3058
# L1_loss:0.1648
# Discriminator_loss:1.6979
#
# EPOCH[1] - STEP[400]
# Generator_loss:17.9907
# L1_loss:0.1577
# Discriminator_loss:0.7582
#
# EPOCH[1] - STEP[410]
# Generator_loss:22.6115
# L1_loss:0.2098
# Discriminator_loss:0.6015
#
# EPOCH[1] - STEP[420]
# Generator_loss:28.6123
# L1_loss:0.2748
# Discriminator_loss:1.6479
#
# EPOCH[1] - STEP[430]
# Generator_loss:18.1042
# L1_loss:0.1636
# Discriminator_loss:1.6776
#
# EPOCH[1] - STEP[440]
# Generator_loss:20.4614
# L1_loss:0.1921
# Discriminator_loss:0.4950
#
# EPOCH[1] - STEP[450]
# Generator_loss:16.5985
# L1_loss:0.1509
# Discriminator_loss:0.4850
#
# EPOCH[1] - STEP[460]
# Generator_loss:17.4718
# L1_loss:0.1473
# Discriminator_loss:1.0700
#
# EPOCH[1] - STEP[470]
# Generator_loss:24.3580
# L1_loss:0.2157
# Discriminator_loss:0.1814
#
# EPOCH[1] - STEP[480]
# Generator_loss:18.7330
# L1_loss:0.1552
# Discriminator_loss:1.9989
#
# EPOCH[1] - STEP[490]
# Generator_loss:19.5513
# L1_loss:0.1792
# Discriminator_loss:0.6231
#
# EPOCH[1] - STEP[500]
# Generator_loss:16.0054
# L1_loss:0.1426
# Discriminator_loss:0.6254
#
# EPOCH[1] - STEP[510]
# Generator_loss:24.9662
# L1_loss:0.2432
# Discriminator_loss:0.9913
#
# EPOCH[1] - STEP[520]
# Generator_loss:17.9786
# L1_loss:0.1629
# Discriminator_loss:0.4781
#
# EPOCH[1] - STEP[530]
# Generator_loss:16.5738
# L1_loss:0.1497
# Discriminator_loss:0.5665
#
# EPOCH[1] - STEP[540]
# Generator_loss:18.6468
# L1_loss:0.1644
# Discriminator_loss:2.0270
#
# EPOCH[1] - STEP[550]
# Generator_loss:24.0887
# L1_loss:0.2238
# Discriminator_loss:0.4011
#
# EPOCH[1] - STEP[560]
# Generator_loss:22.2396
# L1_loss:0.1898
# Discriminator_loss:0.3591
#
# EPOCH[1] - STEP[570]
# Generator_loss:18.2254
# L1_loss:0.1609
# Discriminator_loss:0.9272
#
# EPOCH[1] - STEP[580]
# Generator_loss:21.2783
# L1_loss:0.1980
# Discriminator_loss:0.3855
#
# EPOCH[1] - STEP[590]
# Generator_loss:14.8211
# L1_loss:0.1420
# Discriminator_loss:0.9679
#
# EPOCH[1] - STEP[600]
# Generator_loss:13.6299
# L1_loss:0.1211
# Discriminator_loss:0.6454
#
# EPOCH[1] - STEP[610]
# Generator_loss:20.0553
# L1_loss:0.1843
# Discriminator_loss:0.3484
#
# EPOCH[1] - STEP[620]
# Generator_loss:19.0910
# L1_loss:0.1771
# Discriminator_loss:2.0650
#
# EPOCH[1] - STEP[630]
# Generator_loss:26.9497
# L1_loss:0.2615
# Discriminator_loss:0.8372
#
# EPOCH[1] - STEP[640]
# Generator_loss:15.4135
# L1_loss:0.1474
# Discriminator_loss:1.2715
#
# EPOCH[1] - STEP[650]
# Generator_loss:20.4307
# L1_loss:0.1981
# Discriminator_loss:0.8729
#
# EPOCH[1] - STEP[660]
# Generator_loss:24.0345
# L1_loss:0.2258
# Discriminator_loss:0.3249
#
# EPOCH[1] - STEP[670]
# Generator_loss:23.8423
# L1_loss:0.2248
# Discriminator_loss:0.6324
#
# EPOCH[1] - STEP[680]
# Generator_loss:14.8351
# L1_loss:0.1349
# Discriminator_loss:0.9339
#
# EPOCH[1] - STEP[690]
# Generator_loss:17.5821
# L1_loss:0.1527
# Discriminator_loss:1.7324
#
# EPOCH[1] - STEP[700]
# Generator_loss:22.3028
# L1_loss:0.2021
# Discriminator_loss:1.4827
#
# EPOCH[1] - STEP[710]
# Generator_loss:16.0089
# L1_loss:0.1539
# Discriminator_loss:1.1345
#
# EPOCH[1] - STEP[720]
# Generator_loss:22.9964
# L1_loss:0.2097
# Discriminator_loss:0.3429
#
# EPOCH[1] - STEP[730]
# Generator_loss:25.4180
# L1_loss:0.2280
# Discriminator_loss:1.5811
#
# EPOCH[1] - STEP[740]
# Generator_loss:20.4030
# L1_loss:0.1932
# Discriminator_loss:0.6902
#
# EPOCH[1] - STEP[750]
# Generator_loss:14.2430
# L1_loss:0.1229
# Discriminator_loss:1.2941
#
# EPOCH[1] - STEP[760]
# Generator_loss:17.7178
# L1_loss:0.1630
# Discriminator_loss:0.7332
#
# EPOCH[1] - STEP[770]
# Generator_loss:19.6709
# L1_loss:0.1823
# Discriminator_loss:0.8790
#
# EPOCH[1] - STEP[780]
# Generator_loss:23.5676
# L1_loss:0.2116
# Discriminator_loss:0.4581
#
# EPOCH[1] - STEP[790]
# Generator_loss:13.8015
# L1_loss:0.1231
# Discriminator_loss:0.8232
#
# EPOCH[1] - STEP[800]
# Generator_loss:18.7428
# L1_loss:0.1676
# Discriminator_loss:1.0405
#
# EPOCH[1] - STEP[810]
# Generator_loss:19.5447
# L1_loss:0.1843
# Discriminator_loss:0.5427
#
# EPOCH[1] - STEP[820]
# Generator_loss:16.6592
# L1_loss:0.1514
# Discriminator_loss:0.6520
#
# EPOCH[1] - STEP[830]
# Generator_loss:17.8206
# L1_loss:0.1678
# Discriminator_loss:0.8819
#
# EPOCH[1] - STEP[840]
# Generator_loss:16.7428
# L1_loss:0.1540
# Discriminator_loss:0.8008
#
# EPOCH[1] - STEP[850]
# Generator_loss:16.5694
# L1_loss:0.1490
# Discriminator_loss:0.4024
#
# EPOCH[1] - STEP[860]
# Generator_loss:20.4150
# L1_loss:0.1848
# Discriminator_loss:0.9586
#
# EPOCH[1] - STEP[870]
# Generator_loss:28.3607
# L1_loss:0.2663
# Discriminator_loss:0.3590
#
# EPOCH[1] - STEP[880]
# Generator_loss:22.3103
# L1_loss:0.2123
# Discriminator_loss:0.4901
#
# EPOCH[1] - STEP[890]
# Generator_loss:18.7784
# L1_loss:0.1585
# Discriminator_loss:0.7543
#
# EPOCH[1] - STEP[900]
# Generator_loss:16.8850
# L1_loss:0.1563
# Discriminator_loss:0.6419
#
# EPOCH[1] - STEP[910]
# Generator_loss:21.6797
# L1_loss:0.2133
# Discriminator_loss:2.8800
#
# EPOCH[1] - STEP[920]
# Generator_loss:21.3313
# L1_loss:0.2010
# Discriminator_loss:0.5269
#
# EPOCH[1] - STEP[930]
# Generator_loss:23.4678
# L1_loss:0.2168
# Discriminator_loss:1.2143
#
# EPOCH[1] - STEP[940]
# Generator_loss:18.9195
# L1_loss:0.1705
# Discriminator_loss:1.6072
#
# EPOCH[1] - STEP[950]
# Generator_loss:27.1071
# L1_loss:0.2612
# Discriminator_loss:1.3297
#
# EPOCH[1] - STEP[960]
# Generator_loss:17.8846
# L1_loss:0.1608
# Discriminator_loss:0.2773
#
# EPOCH[1] - STEP[970]
# Generator_loss:18.3015
# L1_loss:0.1700
# Discriminator_loss:0.4473
#
# EPOCH[1] - STEP[980]
# Generator_loss:18.1047
# L1_loss:0.1768
# Discriminator_loss:1.3138
#
# EPOCH[1] - STEP[990]
# Generator_loss:18.7402
# L1_loss:0.1696
# Discriminator_loss:0.5299
#
# EPOCH[1] - STEP[1000]
# Generator_loss:27.2081
# L1_loss:0.2556
# Discriminator_loss:0.3004
#
# EPOCH[2] - STEP[10]
# Generator_loss:16.9426
# L1_loss:0.1488
# Discriminator_loss:1.0291
#
# EPOCH[2] - STEP[20]
# Generator_loss:15.9536
# L1_loss:0.1378
# Discriminator_loss:1.0232
#
# EPOCH[2] - STEP[30]
# Generator_loss:19.7063
# L1_loss:0.1828
# Discriminator_loss:1.7210
#
# EPOCH[2] - STEP[40]
# Generator_loss:19.4172
# L1_loss:0.1888
# Discriminator_loss:1.0790
#
# EPOCH[2] - STEP[50]
# Generator_loss:15.4214
# L1_loss:0.1424
# Discriminator_loss:0.9499
#
# EPOCH[2] - STEP[60]
# Generator_loss:20.5947
# L1_loss:0.1881
# Discriminator_loss:0.7573
#
# EPOCH[2] - STEP[70]
# Generator_loss:21.7221
# L1_loss:0.2046
# Discriminator_loss:0.6520
#
# EPOCH[2] - STEP[80]
# Generator_loss:18.0223
# L1_loss:0.1576
# Discriminator_loss:0.8617
#
# EPOCH[2] - STEP[90]
# Generator_loss:16.0791
# L1_loss:0.1497
# Discriminator_loss:0.6042
#
# EPOCH[2] - STEP[100]
# Generator_loss:18.2116
# L1_loss:0.1663
# Discriminator_loss:0.8709
#
# EPOCH[2] - STEP[110]
# Generator_loss:22.6499
# L1_loss:0.2048
# Discriminator_loss:0.2905
#
# EPOCH[2] - STEP[120]
# Generator_loss:16.3685
# L1_loss:0.1589
# Discriminator_loss:2.1523
#
# EPOCH[2] - STEP[130]
# Generator_loss:19.5347
# L1_loss:0.1845
# Discriminator_loss:0.5394
#
# EPOCH[2] - STEP[140]
# Generator_loss:16.1824
# L1_loss:0.1494
# Discriminator_loss:0.9357
#
# EPOCH[2] - STEP[150]
# Generator_loss:17.7300
# L1_loss:0.1602
# Discriminator_loss:0.7677
#
# EPOCH[2] - STEP[160]
# Generator_loss:16.6335
# L1_loss:0.1503
# Discriminator_loss:1.2483
#
# EPOCH[2] - STEP[170]
# Generator_loss:26.6356
# L1_loss:0.2433
# Discriminator_loss:0.2872
#
# EPOCH[2] - STEP[180]
# Generator_loss:24.1595
# L1_loss:0.2337
# Discriminator_loss:0.8030
#
# EPOCH[2] - STEP[190]
# Generator_loss:17.7263
# L1_loss:0.1576
# Discriminator_loss:0.4041
#
# EPOCH[2] - STEP[200]
# Generator_loss:18.6982
# L1_loss:0.1735
# Discriminator_loss:1.9950
#
# EPOCH[2] - STEP[210]
# Generator_loss:20.2381
# L1_loss:0.1925
# Discriminator_loss:0.5868
#
# EPOCH[2] - STEP[220]
# Generator_loss:25.5551
# L1_loss:0.2356
# Discriminator_loss:0.2997
#
# EPOCH[2] - STEP[230]
# Generator_loss:17.7533
# L1_loss:0.1653
# Discriminator_loss:0.4997
#
# EPOCH[2] - STEP[240]
# Generator_loss:17.5469
# L1_loss:0.1588
# Discriminator_loss:0.5734
#
# EPOCH[2] - STEP[250]
# Generator_loss:24.9320
# L1_loss:0.2274
# Discriminator_loss:0.2465
#
# EPOCH[2] - STEP[260]
# Generator_loss:13.2505
# L1_loss:0.1171
# Discriminator_loss:1.7285
#
# EPOCH[2] - STEP[270]
# Generator_loss:19.0870
# L1_loss:0.1857
# Discriminator_loss:1.1601
#
# EPOCH[2] - STEP[280]
# Generator_loss:15.7546
# L1_loss:0.1357
# Discriminator_loss:1.3432
#
# EPOCH[2] - STEP[290]
# Generator_loss:15.3079
# L1_loss:0.1473
# Discriminator_loss:1.3350
#
# EPOCH[2] - STEP[300]
# Generator_loss:14.9937
# L1_loss:0.1374
# Discriminator_loss:0.7141
#
# EPOCH[2] - STEP[310]
# Generator_loss:17.6003
# L1_loss:0.1617
# Discriminator_loss:0.4016
#
# EPOCH[2] - STEP[320]
# Generator_loss:19.0575
# L1_loss:0.1797
# Discriminator_loss:1.0433
#
# EPOCH[2] - STEP[330]
# Generator_loss:14.6456
# L1_loss:0.1217
# Discriminator_loss:1.7350
#
# EPOCH[2] - STEP[340]
# Generator_loss:16.6541
# L1_loss:0.1578
# Discriminator_loss:0.6247
#
# EPOCH[2] - STEP[350]
# Generator_loss:23.6002
# L1_loss:0.2323
# Discriminator_loss:1.3343
#
# EPOCH[2] - STEP[360]
# Generator_loss:16.2106
# L1_loss:0.1528
# Discriminator_loss:1.3895
#
# EPOCH[2] - STEP[370]
# Generator_loss:27.3385
# L1_loss:0.2536
# Discriminator_loss:0.2895
#
# EPOCH[2] - STEP[380]
# Generator_loss:16.2806
# L1_loss:0.1452
# Discriminator_loss:0.7756
#
# EPOCH[2] - STEP[390]
# Generator_loss:17.1173
# L1_loss:0.1483
# Discriminator_loss:0.6472
#
# EPOCH[2] - STEP[400]
# Generator_loss:21.0942
# L1_loss:0.1975
# Discriminator_loss:0.3891
#
# EPOCH[2] - STEP[410]
# Generator_loss:17.6528
# L1_loss:0.1554
# Discriminator_loss:0.9378
#
# EPOCH[2] - STEP[420]
# Generator_loss:17.4110
# L1_loss:0.1585
# Discriminator_loss:0.7202
#
# EPOCH[2] - STEP[430]
# Generator_loss:20.0661
# L1_loss:0.1702
# Discriminator_loss:1.8553
#
# EPOCH[2] - STEP[440]
# Generator_loss:19.2118
# L1_loss:0.1831
# Discriminator_loss:1.8001
#
# EPOCH[2] - STEP[450]
# Generator_loss:17.2611
# L1_loss:0.1659
# Discriminator_loss:1.5105
#
# EPOCH[2] - STEP[460]
# Generator_loss:17.2533
# L1_loss:0.1471
# Discriminator_loss:1.4787
#
# EPOCH[2] - STEP[470]
# Generator_loss:16.3416
# L1_loss:0.1583
# Discriminator_loss:1.3021
#
# EPOCH[2] - STEP[480]
# Generator_loss:17.5330
# L1_loss:0.1741
# Discriminator_loss:2.4122
#
# EPOCH[2] - STEP[490]
# Generator_loss:16.0950
# L1_loss:0.1562
# Discriminator_loss:1.1232
#
# EPOCH[2] - STEP[500]
# Generator_loss:19.2881
# L1_loss:0.1784
# Discriminator_loss:0.5742
#
# EPOCH[2] - STEP[510]
# Generator_loss:17.1607
# L1_loss:0.1560
# Discriminator_loss:0.6810
#
# EPOCH[2] - STEP[520]
# Generator_loss:27.7816
# L1_loss:0.2635
# Discriminator_loss:0.5348
#
# EPOCH[2] - STEP[530]
# Generator_loss:32.2552
# L1_loss:0.3051
# Discriminator_loss:0.2852
#
# EPOCH[2] - STEP[540]
# Generator_loss:19.9702
# L1_loss:0.1653
# Discriminator_loss:0.7455
#
# EPOCH[2] - STEP[550]
# Generator_loss:16.1186
# L1_loss:0.1465
# Discriminator_loss:0.5496
#
# EPOCH[2] - STEP[560]
# Generator_loss:17.1334
# L1_loss:0.1552
# Discriminator_loss:1.2061
#
# EPOCH[2] - STEP[570]
# Generator_loss:17.4267
# L1_loss:0.1576
# Discriminator_loss:2.1576
#
# EPOCH[2] - STEP[580]
# Generator_loss:19.5576
# L1_loss:0.1794
# Discriminator_loss:1.0038
#
# EPOCH[2] - STEP[590]
# Generator_loss:13.1336
# L1_loss:0.1230
# Discriminator_loss:1.2799
#
# EPOCH[2] - STEP[600]
# Generator_loss:17.9765
# L1_loss:0.1653
# Discriminator_loss:0.7673
#
# EPOCH[2] - STEP[610]
# Generator_loss:22.9384
# L1_loss:0.2086
# Discriminator_loss:0.4754
#
# EPOCH[2] - STEP[620]
# Generator_loss:18.4654
# L1_loss:0.1581
# Discriminator_loss:0.9383
#
# EPOCH[2] - STEP[630]
# Generator_loss:20.7151
# L1_loss:0.1820
# Discriminator_loss:0.2197
#
# EPOCH[2] - STEP[640]
# Generator_loss:16.5180
# L1_loss:0.1467
# Discriminator_loss:0.6803
#
# EPOCH[2] - STEP[650]
# Generator_loss:24.0092
# L1_loss:0.2122
# Discriminator_loss:0.1086
#
# EPOCH[2] - STEP[660]
# Generator_loss:18.1810
# L1_loss:0.1749
# Discriminator_loss:1.0455
#
# EPOCH[2] - STEP[670]
# Generator_loss:27.8347
# L1_loss:0.2650
# Discriminator_loss:0.4013
#
# EPOCH[2] - STEP[680]
# Generator_loss:20.4664
# L1_loss:0.1886
# Discriminator_loss:0.6097
#
# EPOCH[2] - STEP[690]
# Generator_loss:17.0552
# L1_loss:0.1612
# Discriminator_loss:1.0991
#
# EPOCH[2] - STEP[700]
# Generator_loss:21.1296
# L1_loss:0.1979
# Discriminator_loss:0.3652
#
# EPOCH[2] - STEP[710]
# Generator_loss:16.1772
# L1_loss:0.1402
# Discriminator_loss:2.5819
#
# EPOCH[2] - STEP[720]
# Generator_loss:25.2638
# L1_loss:0.2438
# Discriminator_loss:0.6170
#
# EPOCH[2] - STEP[730]
# Generator_loss:14.6703
# L1_loss:0.1358
# Discriminator_loss:1.5236
#
# EPOCH[2] - STEP[740]
# Generator_loss:24.5459
# L1_loss:0.2270
# Discriminator_loss:0.2300
#
# EPOCH[2] - STEP[750]
# Generator_loss:16.2824
# L1_loss:0.1537
# Discriminator_loss:0.7637
#
# EPOCH[2] - STEP[760]
# Generator_loss:15.1090
# L1_loss:0.1445
# Discriminator_loss:0.8733
#
# EPOCH[2] - STEP[770]
# Generator_loss:31.2538
# L1_loss:0.2931
# Discriminator_loss:0.1772
#
# EPOCH[2] - STEP[780]
# Generator_loss:21.4492
# L1_loss:0.1921
# Discriminator_loss:1.2401
#
# EPOCH[2] - STEP[790]
# Generator_loss:20.0360
# L1_loss:0.1797
# Discriminator_loss:1.0342
#
# EPOCH[2] - STEP[800]
# Generator_loss:22.2401
# L1_loss:0.1951
# Discriminator_loss:2.0294
#
# EPOCH[2] - STEP[810]
# Generator_loss:14.6975
# L1_loss:0.1350
# Discriminator_loss:1.9255
#
# EPOCH[2] - STEP[820]
# Generator_loss:24.9547
# L1_loss:0.2392
# Discriminator_loss:0.6255
#
# EPOCH[2] - STEP[830]
# Generator_loss:17.8432
# L1_loss:0.1667
# Discriminator_loss:0.5644
#
# EPOCH[2] - STEP[840]
# Generator_loss:20.5653
# L1_loss:0.1984
# Discriminator_loss:0.7656
#
# EPOCH[2] - STEP[850]
# Generator_loss:27.1637
# L1_loss:0.2660
# Discriminator_loss:0.9488
#
# EPOCH[2] - STEP[860]
# Generator_loss:19.4282
# L1_loss:0.1702
# Discriminator_loss:1.0257
#
# EPOCH[2] - STEP[870]
# Generator_loss:26.2817
# L1_loss:0.2598
# Discriminator_loss:2.2309
#
# EPOCH[2] - STEP[880]
# Generator_loss:15.4797
# L1_loss:0.1409
# Discriminator_loss:0.9030
#
# EPOCH[2] - STEP[890]
# Generator_loss:19.3111
# L1_loss:0.1544
# Discriminator_loss:0.6791
#
# EPOCH[2] - STEP[900]
# Generator_loss:17.2196
# L1_loss:0.1610
# Discriminator_loss:0.7252
#
# EPOCH[2] - STEP[910]
# Generator_loss:19.1097
# L1_loss:0.1721
# Discriminator_loss:0.4750
#
# EPOCH[2] - STEP[920]
# Generator_loss:15.3882
# L1_loss:0.1395
# Discriminator_loss:0.5991
#
# EPOCH[2] - STEP[930]
# Generator_loss:22.1279
# L1_loss:0.2041
# Discriminator_loss:0.2504
#
# EPOCH[2] - STEP[940]
# Generator_loss:21.1724
# L1_loss:0.2002
# Discriminator_loss:0.4486
#
# EPOCH[2] - STEP[950]
# Generator_loss:17.5167
# L1_loss:0.1611
# Discriminator_loss:0.5970
#
# EPOCH[2] - STEP[960]
# Generator_loss:18.0892
# L1_loss:0.1716
# Discriminator_loss:0.6868
#
# EPOCH[2] - STEP[970]
# Generator_loss:17.9929
# L1_loss:0.1595
# Discriminator_loss:1.5433
#
# EPOCH[2] - STEP[980]
# Generator_loss:17.0375
# L1_loss:0.1633
# Discriminator_loss:1.5129
#
# EPOCH[2] - STEP[990]
# Generator_loss:20.4270
# L1_loss:0.1761
# Discriminator_loss:0.2898
#
# EPOCH[2] - STEP[1000]
# Generator_loss:19.7124
# L1_loss:0.1720
# Discriminator_loss:1.1710
#
# EPOCH[3] - STEP[10]
# Generator_loss:24.5117
# L1_loss:0.2196
# Discriminator_loss:2.9762
#
# EPOCH[3] - STEP[20]
# Generator_loss:14.1989
# L1_loss:0.1196
# Discriminator_loss:1.0561
#
# EPOCH[3] - STEP[30]
# Generator_loss:20.8273
# L1_loss:0.1973
# Discriminator_loss:0.5315
#
# EPOCH[3] - STEP[40]
# Generator_loss:16.3954
# L1_loss:0.1464
# Discriminator_loss:1.0060
#
# EPOCH[3] - STEP[50]
# Generator_loss:18.1033
# L1_loss:0.1726
# Discriminator_loss:1.9669
#
# EPOCH[3] - STEP[60]
# Generator_loss:18.6461
# L1_loss:0.1678
# Discriminator_loss:0.4190
#
# EPOCH[3] - STEP[70]
# Generator_loss:16.6900
# L1_loss:0.1548
# Discriminator_loss:1.4727
#
# EPOCH[3] - STEP[80]
# Generator_loss:16.3239
# L1_loss:0.1525
# Discriminator_loss:1.8194
#
# EPOCH[3] - STEP[90]
# Generator_loss:24.7191
# L1_loss:0.2278
# Discriminator_loss:0.1980
#
# EPOCH[3] - STEP[100]
# Generator_loss:15.6179
# L1_loss:0.1375
# Discriminator_loss:1.2663
#
# EPOCH[3] - STEP[110]
# Generator_loss:24.7352
# L1_loss:0.2277
# Discriminator_loss:0.2517
#
# EPOCH[3] - STEP[120]
# Generator_loss:30.3779
# L1_loss:0.2951
# Discriminator_loss:0.6164
#
# EPOCH[3] - STEP[130]
# Generator_loss:19.7586
# L1_loss:0.1809
# Discriminator_loss:1.2437
#
# EPOCH[3] - STEP[140]
# Generator_loss:16.5369
# L1_loss:0.1433
# Discriminator_loss:0.6133
#
# EPOCH[3] - STEP[150]
# Generator_loss:22.2447
# L1_loss:0.2030
# Discriminator_loss:0.2296
#
# EPOCH[3] - STEP[160]
# Generator_loss:21.1659
# L1_loss:0.1995
# Discriminator_loss:1.1468
#
# EPOCH[3] - STEP[170]
# Generator_loss:34.3531
# L1_loss:0.3220
# Discriminator_loss:0.1642
#
# EPOCH[3] - STEP[180]
# Generator_loss:20.4879
# L1_loss:0.1949
# Discriminator_loss:0.7142
#
# EPOCH[3] - STEP[190]
# Generator_loss:14.4241
# L1_loss:0.1318
# Discriminator_loss:0.9845
#
# EPOCH[3] - STEP[200]
# Generator_loss:17.7332
# L1_loss:0.1710
# Discriminator_loss:1.7767
#
# EPOCH[3] - STEP[210]
# Generator_loss:18.1469
# L1_loss:0.1574
# Discriminator_loss:0.7968
#
# EPOCH[3] - STEP[220]
# Generator_loss:15.5373
# L1_loss:0.1373
# Discriminator_loss:1.1343
#
# EPOCH[3] - STEP[230]
# Generator_loss:19.7549
# L1_loss:0.1858
# Discriminator_loss:0.9466
#
# EPOCH[3] - STEP[240]
# Generator_loss:27.2754
# L1_loss:0.2425
# Discriminator_loss:0.1314
#
# EPOCH[3] - STEP[250]
# Generator_loss:24.6720
# L1_loss:0.2314
# Discriminator_loss:0.4348
#
# EPOCH[3] - STEP[260]
# Generator_loss:14.7836
# L1_loss:0.1269
# Discriminator_loss:2.0075
#
# EPOCH[3] - STEP[270]
# Generator_loss:20.5659
# L1_loss:0.1864
# Discriminator_loss:1.3353
#
# EPOCH[3] - STEP[280]
# Generator_loss:19.8761
# L1_loss:0.1864
# Discriminator_loss:2.4505
#
# EPOCH[3] - STEP[290]
# Generator_loss:19.4717
# L1_loss:0.1626
# Discriminator_loss:1.1732
#
# EPOCH[3] - STEP[300]
# Generator_loss:17.6170
# L1_loss:0.1652
# Discriminator_loss:1.0497
#
# EPOCH[3] - STEP[310]
# Generator_loss:24.1088
# L1_loss:0.2331
# Discriminator_loss:0.8197
#
# EPOCH[3] - STEP[320]
# Generator_loss:19.3329
# L1_loss:0.1802
# Discriminator_loss:0.4289
#
# EPOCH[3] - STEP[330]
# Generator_loss:17.6780
# L1_loss:0.1642
# Discriminator_loss:0.4334
#
# EPOCH[3] - STEP[340]
# Generator_loss:16.7934
# L1_loss:0.1605
# Discriminator_loss:3.0905
#
# EPOCH[3] - STEP[350]
# Generator_loss:18.2297
# L1_loss:0.1730
# Discriminator_loss:0.7505
#
# EPOCH[3] - STEP[360]
# Generator_loss:23.3168
# L1_loss:0.2009
# Discriminator_loss:0.3250
#
# EPOCH[3] - STEP[370]
# Generator_loss:23.2949
# L1_loss:0.2220
# Discriminator_loss:0.5403
#
# EPOCH[3] - STEP[380]
# Generator_loss:19.9695
# L1_loss:0.1800
# Discriminator_loss:1.4836
#
# EPOCH[3] - STEP[390]
# Generator_loss:17.5297
# L1_loss:0.1563
# Discriminator_loss:0.5331
#
# EPOCH[3] - STEP[400]
# Generator_loss:22.2339
# L1_loss:0.2077
# Discriminator_loss:0.3537
#
# EPOCH[3] - STEP[410]
# Generator_loss:22.9842
# L1_loss:0.2113
# Discriminator_loss:0.2166
#
# EPOCH[3] - STEP[420]
# Generator_loss:16.5558
# L1_loss:0.1377
# Discriminator_loss:2.0265
#
# EPOCH[3] - STEP[430]
# Generator_loss:16.3470
# L1_loss:0.1561
# Discriminator_loss:1.3008
#
# EPOCH[3] - STEP[440]
# Generator_loss:14.7953
# L1_loss:0.1337
# Discriminator_loss:1.0263
#
# EPOCH[3] - STEP[450]
# Generator_loss:23.2724
# L1_loss:0.2246
# Discriminator_loss:0.6943
#
# EPOCH[3] - STEP[460]
# Generator_loss:14.6119
# L1_loss:0.1250
# Discriminator_loss:1.9596
#
# EPOCH[3] - STEP[470]
# Generator_loss:17.8396
# L1_loss:0.1529
# Discriminator_loss:1.7351
#
# EPOCH[3] - STEP[480]
# Generator_loss:26.0941
# L1_loss:0.2447
# Discriminator_loss:0.2721
#
# EPOCH[3] - STEP[490]
# Generator_loss:24.3989
# L1_loss:0.2374
# Discriminator_loss:0.8092
#
# EPOCH[3] - STEP[500]
# Generator_loss:17.6110
# L1_loss:0.1566
# Discriminator_loss:1.0551
#
# EPOCH[3] - STEP[510]
# Generator_loss:21.0455
# L1_loss:0.2008
# Discriminator_loss:0.6744
#
# EPOCH[3] - STEP[520]
# Generator_loss:20.5908
# L1_loss:0.1885
# Discriminator_loss:1.9173
#
# EPOCH[3] - STEP[530]
# Generator_loss:15.0482
# L1_loss:0.1420
# Discriminator_loss:0.8869
#
# EPOCH[3] - STEP[540]
# Generator_loss:19.8801
# L1_loss:0.1856
# Discriminator_loss:0.3979
#
# EPOCH[3] - STEP[550]
# Generator_loss:19.1750
# L1_loss:0.1729
# Discriminator_loss:0.8470
#
# EPOCH[3] - STEP[560]
# Generator_loss:25.3828
# L1_loss:0.2346
# Discriminator_loss:0.2498
#
# EPOCH[3] - STEP[570]
# Generator_loss:19.1701
# L1_loss:0.1659
# Discriminator_loss:2.0455
#
# EPOCH[3] - STEP[580]
# Generator_loss:16.1911
# L1_loss:0.1438
# Discriminator_loss:1.7681
#
# EPOCH[3] - STEP[590]
# Generator_loss:18.9210
# L1_loss:0.1839
# Discriminator_loss:1.0263
#
# EPOCH[3] - STEP[600]
# Generator_loss:28.5241
# L1_loss:0.2770
# Discriminator_loss:0.6279
#
# EPOCH[3] - STEP[610]
# Generator_loss:18.9731
# L1_loss:0.1785
# Discriminator_loss:2.4085
#
# EPOCH[3] - STEP[620]
# Generator_loss:17.9092
# L1_loss:0.1725
# Discriminator_loss:1.0403
#
# EPOCH[3] - STEP[630]
# Generator_loss:18.8418
# L1_loss:0.1789
# Discriminator_loss:0.6054
#
# EPOCH[3] - STEP[640]
# Generator_loss:24.9556
# L1_loss:0.2325
# Discriminator_loss:0.2866
#
# EPOCH[3] - STEP[650]
# Generator_loss:14.0385
# L1_loss:0.1225
# Discriminator_loss:1.0941
#
# EPOCH[3] - STEP[660]
# Generator_loss:14.8700
# L1_loss:0.1374
# Discriminator_loss:0.9560
#
# EPOCH[3] - STEP[670]
# Generator_loss:23.7849
# L1_loss:0.2205
# Discriminator_loss:0.5102
#
# EPOCH[3] - STEP[680]
# Generator_loss:19.2400
# L1_loss:0.1740
# Discriminator_loss:0.6113
#
# EPOCH[3] - STEP[690]
# Generator_loss:21.0496
# L1_loss:0.1910
# Discriminator_loss:1.9435
#
# EPOCH[3] - STEP[700]
# Generator_loss:15.8450
# L1_loss:0.1479
# Discriminator_loss:2.0472
#
# EPOCH[3] - STEP[710]
# Generator_loss:16.0175
# L1_loss:0.1457
# Discriminator_loss:0.9490
#
# EPOCH[3] - STEP[720]
# Generator_loss:22.4941
# L1_loss:0.2017
# Discriminator_loss:0.3817
#
# EPOCH[3] - STEP[730]
# Generator_loss:16.8875
# L1_loss:0.1588
# Discriminator_loss:0.6771
#
# EPOCH[3] - STEP[740]
# Generator_loss:22.2736
# L1_loss:0.2035
# Discriminator_loss:0.3870
#
# EPOCH[3] - STEP[750]
# Generator_loss:22.7228
# L1_loss:0.2146
# Discriminator_loss:0.4631
#
# EPOCH[3] - STEP[760]
# Generator_loss:14.4089
# L1_loss:0.1394
# Discriminator_loss:1.2858
#
# EPOCH[3] - STEP[770]
# Generator_loss:20.2715
# L1_loss:0.1753
# Discriminator_loss:0.1806
#
# EPOCH[3] - STEP[780]
# Generator_loss:19.7500
# L1_loss:0.1861
# Discriminator_loss:0.9758
#
# EPOCH[3] - STEP[790]
# Generator_loss:17.8602
# L1_loss:0.1605
# Discriminator_loss:1.6231
#
# EPOCH[3] - STEP[800]
# Generator_loss:15.8455
# L1_loss:0.1478
# Discriminator_loss:0.7063
#
# EPOCH[3] - STEP[810]
# Generator_loss:16.3922
# L1_loss:0.1461
# Discriminator_loss:2.1086
#
# EPOCH[3] - STEP[820]
# Generator_loss:16.6620
# L1_loss:0.1583
# Discriminator_loss:0.7588
#
# EPOCH[3] - STEP[830]
# Generator_loss:20.5273
# L1_loss:0.2008
# Discriminator_loss:1.1616
#
# EPOCH[3] - STEP[840]
# Generator_loss:23.4288
# L1_loss:0.2265
# Discriminator_loss:0.7156
#
# EPOCH[3] - STEP[850]
# Generator_loss:17.5010
# L1_loss:0.1612
# Discriminator_loss:1.0473
#
# EPOCH[3] - STEP[860]
# Generator_loss:31.0184
# L1_loss:0.3045
# Discriminator_loss:1.0216
#
# EPOCH[3] - STEP[870]
# Generator_loss:14.7047
# L1_loss:0.1369
# Discriminator_loss:0.8620
#
# EPOCH[3] - STEP[880]
# Generator_loss:18.2022
# L1_loss:0.1673
# Discriminator_loss:0.6952
#
# EPOCH[3] - STEP[890]
# Generator_loss:15.8770
# L1_loss:0.1441
# Discriminator_loss:0.6368
#
# EPOCH[3] - STEP[900]
# Generator_loss:17.3360
# L1_loss:0.1589
# Discriminator_loss:0.4360
#
# EPOCH[3] - STEP[910]
# Generator_loss:19.9294
# L1_loss:0.1948
# Discriminator_loss:1.1381
#
# EPOCH[3] - STEP[920]
# Generator_loss:24.7845
# L1_loss:0.2337
# Discriminator_loss:0.4798
#
# EPOCH[3] - STEP[930]
# Generator_loss:20.3794
# L1_loss:0.1928
# Discriminator_loss:0.8496
#
# EPOCH[3] - STEP[940]
# Generator_loss:15.6342
# L1_loss:0.1470
# Discriminator_loss:2.2248
#
# EPOCH[3] - STEP[950]
# Generator_loss:14.2895
# L1_loss:0.1355
# Discriminator_loss:0.9293
#
# EPOCH[3] - STEP[960]
# Generator_loss:16.8561
# L1_loss:0.1460
# Discriminator_loss:0.7796
#
# EPOCH[3] - STEP[970]
# Generator_loss:16.0027
# L1_loss:0.1495
# Discriminator_loss:1.1642
#
# EPOCH[3] - STEP[980]
# Generator_loss:20.2790
# L1_loss:0.1932
# Discriminator_loss:0.9803
#
# EPOCH[3] - STEP[990]
# Generator_loss:16.6968
# L1_loss:0.1555
# Discriminator_loss:0.9683
#
# EPOCH[3] - STEP[1000]
# Generator_loss:14.7443
# L1_loss:0.1220
# Discriminator_loss:2.9642
#
# EPOCH[4] - STEP[10]
# Generator_loss:21.6454
# L1_loss:0.2056
# Discriminator_loss:0.5136
#
# EPOCH[4] - STEP[20]
# Generator_loss:24.1576
# L1_loss:0.2150
# Discriminator_loss:0.7761
#
# EPOCH[4] - STEP[30]
# Generator_loss:16.8166
# L1_loss:0.1493
# Discriminator_loss:0.5260
#
# EPOCH[4] - STEP[40]
# Generator_loss:20.0051
# L1_loss:0.1914
# Discriminator_loss:0.6372
#
# EPOCH[4] - STEP[50]
# Generator_loss:15.5055
# L1_loss:0.1476
# Discriminator_loss:0.9961
#
# EPOCH[4] - STEP[60]
# Generator_loss:17.1053
# L1_loss:0.1449
# Discriminator_loss:0.9039
#
# EPOCH[4] - STEP[70]
# Generator_loss:18.1153
# L1_loss:0.1618
# Discriminator_loss:1.0275
#
# EPOCH[4] - STEP[80]
# Generator_loss:19.6342
# L1_loss:0.1798
# Discriminator_loss:0.4714
#
# EPOCH[4] - STEP[90]
# Generator_loss:19.0869
# L1_loss:0.1747
# Discriminator_loss:2.0152
#
# EPOCH[4] - STEP[100]
# Generator_loss:24.1962
# L1_loss:0.2246
# Discriminator_loss:0.2444
#
# EPOCH[4] - STEP[110]
# Generator_loss:17.4509
# L1_loss:0.1511
# Discriminator_loss:0.4173
#
# EPOCH[4] - STEP[120]
# Generator_loss:16.3518
# L1_loss:0.1422
# Discriminator_loss:0.4972
#
# EPOCH[4] - STEP[130]
# Generator_loss:17.5220
# L1_loss:0.1496
# Discriminator_loss:0.8765
#
# EPOCH[4] - STEP[140]
# Generator_loss:22.3583
# L1_loss:0.2031
# Discriminator_loss:1.7133
#
# EPOCH[4] - STEP[150]
# Generator_loss:18.0301
# L1_loss:0.1666
# Discriminator_loss:0.8593
#
# EPOCH[4] - STEP[160]
# Generator_loss:13.5830
# L1_loss:0.1322
# Discriminator_loss:2.0946
#
# EPOCH[4] - STEP[170]
# Generator_loss:18.4091
# L1_loss:0.1643
# Discriminator_loss:0.5990
#
# EPOCH[4] - STEP[180]
# Generator_loss:17.0199
# L1_loss:0.1570
# Discriminator_loss:0.6135
#
# EPOCH[4] - STEP[190]
# Generator_loss:19.5589
# L1_loss:0.1731
# Discriminator_loss:1.7487
#
# EPOCH[4] - STEP[200]
# Generator_loss:18.7103
# L1_loss:0.1818
# Discriminator_loss:1.2975
#
# EPOCH[4] - STEP[210]
# Generator_loss:19.4290
# L1_loss:0.1851
# Discriminator_loss:0.7243
#
# EPOCH[4] - STEP[220]
# Generator_loss:22.1740
# L1_loss:0.2072
# Discriminator_loss:0.5473
#
# EPOCH[4] - STEP[230]
# ...
# Generator_loss:13.9091
# L1_loss:0.1373
# Discriminator_loss:2.2657
#
# EPOCH[49] - STEP[950]
# Generator_loss:15.5411
# L1_loss:0.1331
# Discriminator_loss:0.2097
#
# EPOCH[49] - STEP[960]
# Generator_loss:14.0219
# L1_loss:0.1197
# Discriminator_loss:0.6471
#
# EPOCH[49] - STEP[970]
# Generator_loss:27.7353
# L1_loss:0.2673
# Discriminator_loss:0.5568
#
# EPOCH[49] - STEP[980]
# Generator_loss:16.2537
# L1_loss:0.1416
# Discriminator_loss:0.3527
#
# EPOCH[49] - STEP[990]
# Generator_loss:16.1005
# L1_loss:0.1445
# Discriminator_loss:0.4607
#
# EPOCH[49] - STEP[1000]
# Generator_loss:17.9013
# L1_loss:0.1629
# Discriminator_loss:0.8750
#
# EPOCH[50] - STEP[10]
# Generator_loss:15.4654
# L1_loss:0.1362
# Discriminator_loss:0.6514
#
# EPOCH[50] - STEP[20]
# Generator_loss:18.8456
# L1_loss:0.1809
# Discriminator_loss:0.7998
#
# EPOCH[50] - STEP[30]
# Generator_loss:17.2347
# L1_loss:0.1492
# Discriminator_loss:0.3664
#
# EPOCH[50] - STEP[40]
# Generator_loss:19.4744
# L1_loss:0.1694
# Discriminator_loss:0.6462
#
# EPOCH[50] - STEP[50]
# Generator_loss:17.4021
# L1_loss:0.1546
# Discriminator_loss:0.4201
#
# EPOCH[50] - STEP[60]
# Generator_loss:17.9462
# L1_loss:0.1627
# Discriminator_loss:1.3297
#
# EPOCH[50] - STEP[70]
# Generator_loss:18.5467
# L1_loss:0.1733
# Discriminator_loss:0.8418
#
# EPOCH[50] - STEP[80]
# Generator_loss:19.5546
# L1_loss:0.1682
# Discriminator_loss:0.8530
#
# EPOCH[50] - STEP[90]
# Generator_loss:17.8036
# L1_loss:0.1647
# Discriminator_loss:0.9354
#
# EPOCH[50] - STEP[100]
# Generator_loss:15.6475
# L1_loss:0.1461
# Discriminator_loss:0.8639
#
# EPOCH[50] - STEP[110]
# Generator_loss:17.2826
# L1_loss:0.1603
# Discriminator_loss:1.2447
#
# EPOCH[50] - STEP[120]
# Generator_loss:15.3643
# L1_loss:0.1429
# Discriminator_loss:0.7145
#
# EPOCH[50] - STEP[130]
# Generator_loss:13.3259
# L1_loss:0.1275
# Discriminator_loss:1.1666
#
# EPOCH[50] - STEP[140]
# Generator_loss:13.8291
# L1_loss:0.1178
# Discriminator_loss:1.1656
#
# EPOCH[50] - STEP[150]
# Generator_loss:10.9676
# L1_loss:0.0948
# Discriminator_loss:1.2379
#
# EPOCH[50] - STEP[160]
# Generator_loss:18.0597
# L1_loss:0.1672
# Discriminator_loss:0.6217
#
# EPOCH[50] - STEP[170]
# Generator_loss:26.2510
# L1_loss:0.2381
# Discriminator_loss:0.1316
#
# EPOCH[50] - STEP[180]
# Generator_loss:12.2387
# L1_loss:0.0996
# Discriminator_loss:1.0996
#
# EPOCH[50] - STEP[190]
# Generator_loss:18.6517
# L1_loss:0.1541
# Discriminator_loss:0.2754
#
# EPOCH[50] - STEP[200]
# Generator_loss:14.2325
# L1_loss:0.1267
# Discriminator_loss:0.3795
#
# EPOCH[50] - STEP[210]
# Generator_loss:23.0445
# L1_loss:0.2141
# Discriminator_loss:0.2900
#
# EPOCH[50] - STEP[220]
# Generator_loss:13.8960
# L1_loss:0.1255
# Discriminator_loss:1.1756
#
# EPOCH[50] - STEP[230]
# Generator_loss:14.0680
# L1_loss:0.1156
# Discriminator_loss:0.9719
#
# EPOCH[50] - STEP[240]
# Generator_loss:16.9938
# L1_loss:0.1599
# Discriminator_loss:1.0582
#
# EPOCH[50] - STEP[250]
# Generator_loss:21.2870
# L1_loss:0.1991
# Discriminator_loss:0.4068
#
# EPOCH[50] - STEP[260]
# Generator_loss:17.2397
# L1_loss:0.1606
# Discriminator_loss:0.5429
#
# EPOCH[50] - STEP[270]
# Generator_loss:17.5621
# L1_loss:0.1642
# Discriminator_loss:0.8272
#
# EPOCH[50] - STEP[280]
# Generator_loss:15.3383
# L1_loss:0.1434
# Discriminator_loss:0.8616
#
# EPOCH[50] - STEP[290]
# Generator_loss:19.6311
# L1_loss:0.1803
# Discriminator_loss:1.1892
#
# EPOCH[50] - STEP[300]
# Generator_loss:20.6905
# L1_loss:0.1906
# Discriminator_loss:0.3429
#
# EPOCH[50] - STEP[310]
# Generator_loss:20.5053
# L1_loss:0.1941
# Discriminator_loss:0.6514
#
# EPOCH[50] - STEP[320]
# Generator_loss:12.6187
# L1_loss:0.1164
# Discriminator_loss:0.8599
#
# EPOCH[50] - STEP[330]
# Generator_loss:14.3865
# L1_loss:0.1326
# Discriminator_loss:0.9890
#
# EPOCH[50] - STEP[340]
# Generator_loss:18.1892
# L1_loss:0.1714
# Discriminator_loss:1.0230
#
# EPOCH[50] - STEP[350]
# Generator_loss:14.0443
# L1_loss:0.1067
# Discriminator_loss:1.9956
#
# EPOCH[50] - STEP[360]
# Generator_loss:18.9664
# L1_loss:0.1805
# Discriminator_loss:0.7600
#
# EPOCH[50] - STEP[370]
# Generator_loss:13.2738
# L1_loss:0.1183
# Discriminator_loss:1.0723
#
# EPOCH[50] - STEP[380]
# Generator_loss:15.7905
# L1_loss:0.1467
# Discriminator_loss:0.6420
#
# EPOCH[50] - STEP[390]
# Generator_loss:16.2518
# L1_loss:0.1552
# Discriminator_loss:0.8182
#
# EPOCH[50] - STEP[400]
# Generator_loss:16.0546
# L1_loss:0.1373
# Discriminator_loss:0.3409
#
# EPOCH[50] - STEP[410]
# Generator_loss:27.0031
# L1_loss:0.2570
# Discriminator_loss:0.6574
#
# EPOCH[50] - STEP[420]
# Generator_loss:17.0967
# L1_loss:0.1519
# Discriminator_loss:0.6206
#
# EPOCH[50] - STEP[430]
# Generator_loss:16.2127
# L1_loss:0.1491
# Discriminator_loss:0.7266
#
# EPOCH[50] - STEP[440]
# Generator_loss:16.3991
# L1_loss:0.1552
# Discriminator_loss:0.9600
#
# EPOCH[50] - STEP[450]
# Generator_loss:19.9435
# L1_loss:0.1895
# Discriminator_loss:0.6264
#
# EPOCH[50] - STEP[460]
# Generator_loss:16.7482
# L1_loss:0.1455
# Discriminator_loss:0.4043
#
# EPOCH[50] - STEP[470]
# Generator_loss:12.8026
# L1_loss:0.1070
# Discriminator_loss:1.0217
#
# EPOCH[50] - STEP[480]
# Generator_loss:21.0087
# L1_loss:0.1884
# Discriminator_loss:0.1679
#
# EPOCH[50] - STEP[490]
# Generator_loss:18.0662
# L1_loss:0.1608
# Discriminator_loss:0.6306
#
# EPOCH[50] - STEP[500]
# Generator_loss:15.6796
# L1_loss:0.1289
# Discriminator_loss:1.9981
#
# EPOCH[50] - STEP[510]
# Generator_loss:23.0786
# L1_loss:0.2022
# Discriminator_loss:0.1819
#
# EPOCH[50] - STEP[520]
# Generator_loss:16.8734
# L1_loss:0.1402
# Discriminator_loss:1.8286
#
# EPOCH[50] - STEP[530]
# Generator_loss:18.3731
# L1_loss:0.1497
# Discriminator_loss:1.9301
#
# EPOCH[50] - STEP[540]
# Generator_loss:16.1709
# L1_loss:0.1481
# Discriminator_loss:0.8211
#
# EPOCH[50] - STEP[550]
# Generator_loss:13.4211
# L1_loss:0.1231
# Discriminator_loss:1.0378
#
# EPOCH[50] - STEP[560]
# Generator_loss:14.2011
# L1_loss:0.1179
# Discriminator_loss:1.1919
#
# EPOCH[50] - STEP[570]
# Generator_loss:18.1791
# L1_loss:0.1583
# Discriminator_loss:0.2923
#
# EPOCH[50] - STEP[580]
# Generator_loss:18.9384
# L1_loss:0.1696
# Discriminator_loss:0.1957
#
# EPOCH[50] - STEP[590]
# Generator_loss:15.7261
# L1_loss:0.1459
# Discriminator_loss:1.4488
#
# EPOCH[50] - STEP[600]
# Generator_loss:14.7233
# L1_loss:0.1263
# Discriminator_loss:1.7083
#
# EPOCH[50] - STEP[610]
# Generator_loss:20.8351
# L1_loss:0.1805
# Discriminator_loss:0.1352
#
# EPOCH[50] - STEP[620]
# Generator_loss:12.5288
# L1_loss:0.1165
# Discriminator_loss:0.9441
#
# EPOCH[50] - STEP[630]
# Generator_loss:25.2248
# L1_loss:0.2383
# Discriminator_loss:0.4498
#
# EPOCH[50] - STEP[640]
# Generator_loss:24.9785
# L1_loss:0.2246
# Discriminator_loss:0.1687
#
# EPOCH[50] - STEP[650]
# Generator_loss:27.0765
# L1_loss:0.2527
# Discriminator_loss:0.3144
#
# EPOCH[50] - STEP[660]
# Generator_loss:13.7840
# L1_loss:0.1245
# Discriminator_loss:1.1979
#
# EPOCH[50] - STEP[670]
# Generator_loss:17.6316
# L1_loss:0.1645
# Discriminator_loss:0.6920
#
# EPOCH[50] - STEP[680]
# Generator_loss:17.3605
# L1_loss:0.1506
# Discriminator_loss:1.0651
#
# EPOCH[50] - STEP[690]
# Generator_loss:14.5429
# L1_loss:0.1331
# Discriminator_loss:1.0780
#
# EPOCH[50] - STEP[700]
# Generator_loss:17.7290
# L1_loss:0.1532
# Discriminator_loss:0.5859
#
# EPOCH[50] - STEP[710]
# Generator_loss:16.5093
# L1_loss:0.1523
# Discriminator_loss:0.5171
#
# EPOCH[50] - STEP[720]
# Generator_loss:21.9684
# L1_loss:0.1984
# Discriminator_loss:0.1978
#
# EPOCH[50] - STEP[730]
# Generator_loss:16.7566
# L1_loss:0.1585
# Discriminator_loss:0.9854
#
# EPOCH[50] - STEP[740]
# Generator_loss:13.1947
# L1_loss:0.1177
# Discriminator_loss:0.8849
#
# EPOCH[50] - STEP[750]
# Generator_loss:16.5761
# L1_loss:0.1380
# Discriminator_loss:1.5649
#
# EPOCH[50] - STEP[760]
# Generator_loss:13.3341
# L1_loss:0.1182
# Discriminator_loss:1.2328
#
# EPOCH[50] - STEP[770]
# Generator_loss:18.1672
# L1_loss:0.1632
# Discriminator_loss:0.2956
#
# EPOCH[50] - STEP[780]
# Generator_loss:19.4852
# L1_loss:0.1739
# Discriminator_loss:0.2861
#
# EPOCH[50] - STEP[790]
# Generator_loss:17.1358
# L1_loss:0.1645
# Discriminator_loss:1.3534
#
# EPOCH[50] - STEP[800]
# Generator_loss:17.9016
# L1_loss:0.1539
# Discriminator_loss:1.3627
#
# EPOCH[50] - STEP[810]
# Generator_loss:17.5243
# L1_loss:0.1642
# Discriminator_loss:0.8767
#
# EPOCH[50] - STEP[820]
# Generator_loss:19.2279
# L1_loss:0.1879
# Discriminator_loss:1.3048
#
# EPOCH[50] - STEP[830]
# Generator_loss:20.1458
# L1_loss:0.1807
# Discriminator_loss:0.3756
#
# EPOCH[50] - STEP[840]
# Generator_loss:15.5866
# L1_loss:0.1471
# Discriminator_loss:1.2025
#
# EPOCH[50] - STEP[850]
# Generator_loss:14.5247
# L1_loss:0.1192
# Discriminator_loss:1.2274
#
# EPOCH[50] - STEP[860]
# Generator_loss:16.7051
# L1_loss:0.1266
# Discriminator_loss:1.2982
#
# EPOCH[50] - STEP[870]
# Generator_loss:14.8405
# L1_loss:0.1421
# Discriminator_loss:1.0214
#
# EPOCH[50] - STEP[880]
# Generator_loss:17.7672
# L1_loss:0.1690
# Discriminator_loss:0.7631
#
# EPOCH[50] - STEP[890]
# Generator_loss:19.5221
# L1_loss:0.1847
# Discriminator_loss:0.5406
#
# EPOCH[50] - STEP[900]
# Generator_loss:17.1334
# L1_loss:0.1536
# Discriminator_loss:0.3396
#
# EPOCH[50] - STEP[910]
# Generator_loss:16.5444
# L1_loss:0.1423
# Discriminator_loss:0.5039
#
# EPOCH[50] - STEP[920]
# Generator_loss:17.1880
# L1_loss:0.1535
# Discriminator_loss:0.5334
#
# EPOCH[50] - STEP[930]
# Generator_loss:16.0261
# L1_loss:0.1313
# Discriminator_loss:1.6045
#
# EPOCH[50] - STEP[940]
# Generator_loss:18.0881
# L1_loss:0.1669
# Discriminator_loss:0.9935
#
# EPOCH[50] - STEP[950]
# Generator_loss:19.6099
# L1_loss:0.1738
# Discriminator_loss:0.2315
#
# EPOCH[50] - STEP[960]
# Generator_loss:15.4220
# L1_loss:0.1450
# Discriminator_loss:0.9878
#
# EPOCH[50] - STEP[970]
# Generator_loss:16.9932
# L1_loss:0.1466
# Discriminator_loss:0.4675
#
# EPOCH[50] - STEP[980]
# Generator_loss:14.5918
# L1_loss:0.1317
# Discriminator_loss:0.9593
#
# EPOCH[50] - STEP[990]
# Generator_loss:17.8091
# L1_loss:0.1637
# Discriminator_loss:0.5059
#
# EPOCH[50] - STEP[1000]
# Generator_loss:19.0064
# L1_loss:0.1654
# Discriminator_loss:0.3968

# %%
def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

test_ind = 1
val_path = data_path + 'val/'
f = val_path + os.listdir(val_path)[test_ind]
input_image_val, real_image_val = load(f)

input_image_val, real_image_val = normalize(input_image_val, real_image_val)

pred_image = generator(tf.expand_dims(input_image_val, 0))
pred_image = denormalize(pred_image)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(input_image_val))
plt.subplot(1,3,2); plt.imshow(pred_image[0])
plt.subplot(1,3,3); plt.imshow(denormalize(real_image_val))

# %% [markdown]
# ㅠㅠ
